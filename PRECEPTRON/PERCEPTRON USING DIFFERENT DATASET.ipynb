# %%
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# Create a simple linearly separable dataset
mean_class1 = [2, 3]
covariance_class1 = [[1, 0.5], [0.5, 1]]
class1_data = np.random.multivariate_normal(mean_class1, covariance_class1, 100)

mean_class2 = [6, 7]
covariance_class2 = [[1, -0.5], [-0.5, 1]]
class2_data = np.random.multivariate_normal(mean_class2, covariance_class2, 100)

# Combine the two classes
X = np.vstack((class1_data, class2_data))
y = np.hstack((np.zeros(100), np.ones(100)))

# Plot the dataset
plt.scatter(class1_data[:, 0], class1_data[:, 1], label='Class 0', marker='o')
plt.scatter(class2_data[:, 0], class2_data[:, 1], label='Class 1', marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Simple Linearly Separable Dataset')
plt.show()

# %%
class Perceptron:
    def __init__(self, learning_rate=0.01, n_iterations=1000):
        self.learning_rate = learning_rate
        self.n_iterations = n_iterations
        self.weights = None
        self.bias = None

    def train(self, X, y):
        # Initialize weights and bias
        self.weights = np.zeros(X.shape[1])
        self.bias = 0

        for _ in range(self.n_iterations):
            for xi, target in zip(X, y):
                # Update weights and bias
                update = self.learning_rate * (target - self.predict(xi))
                self.weights += update * xi
                self.bias += update

    def predict(self, X):
        # Return the predicted class label
        return np.dot(X, self.weights) + self.bias

# Add a bias term to the input data
X_with_bias = np.c_[np.ones(X.shape[0]), X]

# Initialize and train the perceptron
perceptron = Perceptron(learning_rate=0.1, n_iterations=1000)
perceptron.train(X_with_bias, y)

# Plot the decision boundary
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))

Z = perceptron.predict(np.c_[np.ones(xx.ravel().shape[0]), xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.3)
plt.scatter(class1_data[:, 0], class1_data[:, 1], label='Class 0', marker='o')
plt.scatter(class2_data[:, 0], class2_data[:, 1], label='Class 1', marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Perceptron Decision Boundary')
plt.show()
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_29992\1672386823.py:17: RuntimeWarning: invalid value encountered in add
#   self.weights += update * xi
# C:\Users\Hi\AppData\Local\Temp\ipykernel_29992\1672386823.py:18: RuntimeWarning: invalid value encountered in double_scalars
#   self.bias += update
# C:\Users\Hi\anaconda3\lib\site-packages\matplotlib\contour.py:1454: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# C:\Users\Hi\anaconda3\lib\site-packages\matplotlib\contour.py:1455: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())

# %% [markdown]
# # 2

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# Create a non-linearly separable dataset
mean_class1 = [2, 3]
covariance_class1 = [[1, 0.5], [0.5, 1]]
class1_data = np.random.multivariate_normal(mean_class1, covariance_class1, 100)

mean_class2 = [5, 6]
covariance_class2 = [[1, 0.5], [0.5, 1]]
class2_data = np.random.multivariate_normal(mean_class2, covariance_class2, 100)

# Combine the two classes
X = np.vstack((class1_data, class2_data))
y = np.hstack((np.zeros(100), np.ones(100)))

# Plot the dataset
plt.scatter(class1_data[:, 0], class1_data[:, 1], label='Class 0', marker='o')
plt.scatter(class2_data[:, 0], class2_data[:, 1], label='Class 1', marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Non-linearly Separable Dataset')
plt.show()

# %%
# Add a bias term to the input data
X_with_bias = np.c_[np.ones(X.shape[0]), X]

# Initialize and train the perceptron
perceptron = Perceptron(learning_rate=0.1, n_iterations=1000)
perceptron.train(X_with_bias, y)

# Plot the decision boundary
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))

Z = perceptron.predict(np.c_[np.ones(xx.ravel().shape[0]), xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.3)
plt.scatter(class1_data[:, 0], class1_data[:, 1], label='Class 0', marker='o')
plt.scatter(class2_data[:, 0], class2_data[:, 1], label='Class 1', marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Perceptron Decision Boundary on Non-linearly Separable Dataset')
plt.show()
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_29992\1672386823.py:17: RuntimeWarning: invalid value encountered in add
#   self.weights += update * xi
# C:\Users\Hi\AppData\Local\Temp\ipykernel_29992\1672386823.py:18: RuntimeWarning: invalid value encountered in double_scalars
#   self.bias += update

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# Create linearly separable dataset
mean_class1_linear = [2, 3]
covariance_class1_linear = [[1, 0.5], [0.5, 1]]
class1_data_linear = np.random.multivariate_normal(mean_class1_linear, covariance_class1_linear, 100)

mean_class2_linear = [6, 7]
covariance_class2_linear = [[1, -0.5], [-0.5, 1]]
class2_data_linear = np.random.multivariate_normal(mean_class2_linear, covariance_class2_linear, 100)

# Combine the two classes
X_linear = np.vstack((class1_data_linear, class2_data_linear))
y_linear = np.hstack((np.zeros(100), np.ones(100)))

# Create non-linearly separable dataset
mean_class1_nonlinear = [2, 3]
covariance_class1_nonlinear = [[1, 0.5], [0.5, 1]]
class1_data_nonlinear = np.random.multivariate_normal(mean_class1_nonlinear, covariance_class1_nonlinear, 100)

mean_class2_nonlinear = [5, 6]
covariance_class2_nonlinear = [[1, 0.5], [0.5, 1]]
class2_data_nonlinear = np.random.multivariate_normal(mean_class2_nonlinear, covariance_class2_nonlinear, 100)

# Combine the two classes
X_nonlinear = np.vstack((class1_data_nonlinear, class2_data_nonlinear))
y_nonlinear = np.hstack((np.zeros(100), np.ones(100)))

# Plot both datasets
plt.figure(figsize=(12, 5))

# Plot linearly separable dataset
plt.subplot(1, 2, 1)
plt.scatter(class1_data_linear[:, 0], class1_data_linear[:, 1], label='Class 0', marker='o')
plt.scatter(class2_data_linear[:, 0], class2_data_linear[:, 1], label='Class 1', marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Linearly Separable Dataset')

# Add a bias term to the input data for linear dataset
X_linear_with_bias = np.c_[np.ones(X_linear.shape[0]), X_linear]

# Initialize and train the perceptron for linear dataset
perceptron_linear = Perceptron(learning_rate=0.1, n_iterations=1000)
perceptron_linear.train(X_linear_with_bias, y_linear)

# Plot the decision boundary for linear dataset
x_min, x_max = X_linear[:, 0].min() - 1, X_linear[:, 0].max() + 1
y_min, y_max = X_linear[:, 1].min() - 1, X_linear[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))

Z_linear = perceptron_linear.predict(np.c_[np.ones(xx.ravel().shape[0]), xx.ravel(), yy.ravel()])
Z_linear = Z_linear.reshape(xx.shape)

plt.contourf(xx, yy, Z_linear, alpha=0.3)
plt.scatter(class1_data_linear[:, 0], class1_data_linear[:, 1], label='Class 0', marker='o')
plt.scatter(class2_data_linear[:, 0], class2_data_linear[:, 1], label='Class 1', marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Perceptron Decision Boundary (Linear Dataset)')

# Plot non-linearly separable dataset
plt.subplot(1, 2, 2)
plt.scatter(class1_data_nonlinear[:, 0], class1_data_nonlinear[:, 1], label='Class 0', marker='o')
plt.scatter(class2_data_nonlinear[:, 0], class2_data_nonlinear[:, 1], label='Class 1', marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Non-linearly Separable Dataset')

# Add a bias term to the input data for nonlinear dataset
X_nonlinear_with_bias = np.c_[np.ones(X_nonlinear.shape[0]), X_nonlinear]

# Initialize and train the perceptron for nonlinear dataset
perceptron_nonlinear = Perceptron(learning_rate=0.1, n_iterations=1000)
perceptron_nonlinear.train(X_nonlinear_with_bias, y_nonlinear)

# Plot the decision boundary for nonlinear dataset
x_min, x_max = X_nonlinear[:, 0].min() - 1, X_nonlinear[:, 0].max() + 1
y_min, y_max = X_nonlinear[:, 1].min() - 1, X_nonlinear[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))

Z_nonlinear = perceptron_nonlinear.predict(np.c_[np.ones(xx.ravel().shape[0]), xx.ravel(), yy.ravel()])
Z_nonlinear = Z_nonlinear.reshape(xx.shape)

plt.contourf(xx, yy, Z_nonlinear, alpha=0.3)
plt.scatter(class1_data_nonlinear[:, 0], class1_data_nonlinear[:, 1], label='Class 0', marker='o')
plt.scatter(class2_data_nonlinear[:, 0], class2_data_nonlinear[:, 1], label='Class 1', marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Perceptron Decision Boundary (Non-linear Dataset)')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_29992\1672386823.py:17: RuntimeWarning: invalid value encountered in add
#   self.weights += update * xi
# C:\Users\Hi\AppData\Local\Temp\ipykernel_29992\1672386823.py:18: RuntimeWarning: invalid value encountered in double_scalars
#   self.bias += update

# %% [markdown]
# # 3

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# Generate a synthetic dataset
X, y = make_classification(n_samples=200, n_features=2, n_classes=2, n_clusters_per_class=1, n_redundant=0, random_state=42)

# Plot the dataset
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Synthetic Classification Dataset')
plt.show()

# %%
class Perceptron:
    def __init__(self, learning_rate=0.01, n_iterations=1000):
        self.learning_rate = learning_rate
        self.n_iterations = n_iterations
        self.weights = None
        self.bias = None

    def train(self, X, y):
        # Initialize weights and bias
        self.weights = np.zeros(X.shape[1])
        self.bias = 0

        for _ in range(self.n_iterations):
            for xi, target in zip(X, y):
                # Update weights and bias
                update = self.learning_rate * (target - self.predict(xi))
                self.weights += update * xi
                self.bias += update

    def predict(self, X):
        # Return the predicted class label
        return np.dot(X, self.weights) + self.bias

# Add a bias term to the input data
X_with_bias = np.c_[np.ones(X.shape[0]), X]

# Initialize and train the perceptron
perceptron = Perceptron(learning_rate=0.1, n_iterations=1000)
perceptron.train(X_with_bias, y)

# Plot the decision boundary
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))

Z = perceptron.predict(np.c_[np.ones(xx.ravel().shape[0]), xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the dataset
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.Paired)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Perceptron Decision Boundary on Synthetic Dataset')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# Set random seed for reproducibility
np.random.seed(42)

# Create first dataset using make_classification
X1, y1 = make_classification(n_samples=200, n_features=2, n_informative=2, n_redundant=0,
                             n_clusters_per_class=1, flip_y=0, class_sep=1.5, random_state=42)

# Create second dataset with different characteristics
X2, y2 = make_classification(n_samples=200, n_features=2, n_informative=2, n_redundant=0,
                             n_clusters_per_class=1, flip_y=0.1, class_sep=1, random_state=24)

# Plot both datasets
plt.figure(figsize=(12, 5))

# Plot the first dataset
plt.subplot(1, 2, 1)
plt.scatter(X1[y1 == 0][:, 0], X1[y1 == 0][:, 1], label='Class 0', marker='o')
plt.scatter(X1[y1 == 1][:, 0], X1[y1 == 1][:, 1], label='Class 1', marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Dataset 1')

# Add a bias term to the input data for the first dataset
X1_with_bias = np.c_[np.ones(X1.shape[0]), X1]

# Initialize and train the perceptron for the first dataset
perceptron1 = Perceptron(learning_rate=0.1, n_iterations=1000)
perceptron1.train(X1_with_bias, y1)

# Plot the decision boundary for the first dataset
x1_min, x1_max = X1[:, 0].min() - 1, X1[:, 0].max() + 1
y1_min, y1_max = X1[:, 1].min() - 1, X1[:, 1].max() + 1
xx1, yy1 = np.meshgrid(np.arange(x1_min, x1_max, 0.01), np.arange(y1_min, y1_max, 0.01))

Z1 = perceptron1.predict(np.c_[np.ones(xx1.ravel().shape[0]), xx1.ravel(), yy1.ravel()])
Z1 = Z1.reshape(xx1.shape)

plt.contourf(xx1, yy1, Z1, alpha=0.3)
plt.scatter(X1[y1 == 0][:, 0], X1[y1 == 0][:, 1], label='Class 0', marker='o')
plt.scatter(X1[y1 == 1][:, 0], X1[y1 == 1][:, 1], label='Class 1', marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Perceptron Decision Boundary (Dataset 1)')

# Plot the second dataset
plt.subplot(1, 2, 2)
plt.scatter(X2[y2 == 0][:, 0], X2[y2 == 0][:, 1], label='Class 0', marker='o')
plt.scatter(X2[y2 == 1][:, 0], X2[y2 == 1][:, 1], label='Class 1', marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Dataset 2')

# Add a bias term to the input data for the second dataset
X2_with_bias = np.c_[np.ones(X2.shape[0]), X2]

# Initialize and train the perceptron for the second dataset
perceptron2 = Perceptron(learning_rate=0.1, n_iterations=1000)
perceptron2.train(X2_with_bias, y2)

# Plot the decision boundary for the second dataset
x2_min, x2_max = X2[:, 0].min() - 1, X2[:, 0].max() + 1
y2_min, y2_max = X2[:, 1].min() - 1, X2[:, 1].max() + 1
xx2, yy2 = np.meshgrid(np.arange(x2_min, x2_max, 0.01), np.arange(y2_min, y2_max, 0.01))

Z2 = perceptron2.predict(np.c_[np.ones(xx2.ravel().shape[0]), xx2.ravel(), yy2.ravel()])
Z2 = Z2.reshape(xx2.shape)

plt.contourf(xx2, yy2, Z2, alpha=0.3)
plt.scatter(X2[y2 == 0][:, 0], X2[y2 == 0][:, 1], label='Class 0', marker='o')
plt.scatter(X2[y2 == 1][:, 0], X2[y2 == 1][:, 1], label='Class 1', marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Perceptron Decision Boundary (Dataset 2)')

plt.tight_layout()
plt.show()
